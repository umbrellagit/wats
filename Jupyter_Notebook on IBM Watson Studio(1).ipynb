# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
#  **Evan**
#
#
#  IT Help

# %% [markdown]
# *I am intererested in data science because I am interested in social sciences.*

# %% [markdown]
# ### This code introduces itself.

# %%
print("hi")
# Out:
# hi

# %% [markdown]
# * pow
# * pow
# 3. pow
#
# https://www.coursera.org/learn/open-source-tools-for-data-science/ungradedWidget/c1F5I/instructions-create-and-share-your-jupyter-notebook
#
# ![image.png](attachment:0a7a2eaf-82d3-45ce-b16f-8941cacab66c.png)![image.png](attachment:d3b4b4a5-3ed6-4de6-bbd0-cd816d6958d4.png)
